# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("insurance.csv")
df.shape
# Out:
# (1338, 7)

# %%
# pre-processing the data: sex and smokers using binary values and region using onehot encoding
df = df.dropna(subset=['sex'])
df = df.dropna(subset=['smoker'])
df['sex'] = df['sex'].map({'male': 0, 'female': 1})
df['smoker'] = df['smoker'].map({'yes': 1, 'no': 0})
df = pd.get_dummies(df, columns=['region'], drop_first=False, dtype=float)
# Out:
#       age  sex     bmi  children  smoker      charges  region_northeast  \
# 0      19    1  27.900         0       1  16884.92400               0.0
# 1      18    0  33.770         1       0   1725.55230               0.0
# 2      28    0  33.000         3       0   4449.46200               0.0
# 3      33    0  22.705         0       0  21984.47061               0.0
# 4      32    0  28.880         0       0   3866.85520               0.0
# ...   ...  ...     ...       ...     ...          ...               ...
# 1333   50    0  30.970         3       0  10600.54830               0.0
# 1334   18    1  31.920         0       0   2205.98080               1.0
# 1335   18    1  36.850         0       0   1629.83350               0.0
# 1336   21    1  25.800         0       0   2007.94500               0.0
# 1337   61    1  29.070         0       1  29141.36030               0.0
#
#       region_northwest  region_southeast  region_southwest
# ...

# %%
Y= df['charges'].values
X_raw = df.drop('charges', axis=1).values

X_raw.shape
# Out:
# (1338, 9)

# %%
bias = np.ones((X_raw.shape[0], 1))
X= np.hstack((bias, X_raw)) # X matrix
